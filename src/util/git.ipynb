# %% [markdown]
# # Setup

# %%
# Google drive setup
from google.colab import drive
from os.path import join
from os import chdir

MOUNT_PATH_DRIVE = '/content/drive'
BASE_PATH = join(
      MOUNT_PATH_DRIVE, 
      "MyDrive/barco_skin_lesion_classification"
  )
CODE_PATH = join(BASE_PATH, 'src/')

# Mount the google drive
drive.mount(MOUNT_PATH_DRIVE)

# Set the base path of the project
chdir(CODE_PATH)

# Setup Github credentials
# !git config --global user.email "robbedegroeve@gmail.com"
# !git config --global user.name "RobbeRDG"
# !git config --global user.password "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"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Pull

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# # Commit

# %%
# !git add .
# !git commit -m "updates via collab"
# Out:
# [main 428ef1a] updates via collab
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite src/util/git.ipynb (98%)

# %% [markdown]
# # Push

# %%
# !git push origin main
# Out:
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 2.07 KiB | 353.00 KiB/s, done.
# Total 10 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 3 local objects.
# To https://github.com/RobbeRDG/barco_skin_lesion_classification.git
#    91c9fc9..428ef1a  main -> main
