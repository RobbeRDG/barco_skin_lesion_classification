# %% [markdown]
# # Setup

# %%
# Google drive setup
from google.colab import drive
from os.path import join
from os import chdir

MOUNT_PATH_DRIVE = '/content/drive'
BASE_PATH = join(
      MOUNT_PATH_DRIVE, 
      "MyDrive/barco_skin_lesion_classification"
  )
CODE_PATH = join(BASE_PATH, 'src/')

# Mount the google drive
drive.mount(MOUNT_PATH_DRIVE)

# Set the base path of the project
chdir(CODE_PATH)

# Setup Github credentials
# !git config --global user.email "robbedegroeve@gmail.com"
# !git config --global user.name "RobbeRDG"
# !git config --global user.password "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"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pull

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# # Commit

# %%
# !git add .
# !git commit -m "updates via collab"
# Out:
# [main 4a75291] updates via collab
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# # Push

# %%
# !git push origin main
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://RobbeRDG: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@github.com/RobbeRDG/barco_skin_lesion_classification.git/'

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/RobbeRDG/barco_skin_lesion_classification.git (fetch)
# origin	https://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@github.com/RobbeRDG/barco_skin_lesion_classification.git (push)

# %%
# !git remote set-url origin https://RobbeRDG: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@github.com/RobbeRDG/barco_skin_lesion_classification.git

# %%
# !git config --global credential.helper
