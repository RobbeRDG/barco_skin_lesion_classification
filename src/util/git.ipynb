# %%
# Google drive setup
from google.colab import drive
from os.path import join
from os import chdir

MOUNT_PATH_DRIVE = '/content/drive'
BASE_PATH = join(
      MOUNT_PATH_DRIVE, 
      "MyDrive/barco_skin_lesion_classification"
  )
CODE_PATH = join(BASE_PATH, 'src/')

# Mount the google drive
drive.mount(MOUNT_PATH_DRIVE)

# Set the base path of the project
chdir(CODE_PATH)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Config

# %%
# !git config --global user.email "robbedegroeve@gmail.com"
# !git config --global user.name "RobbeRDG"

# %% [markdown]
# # Pull

# %%
# !git pull
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %% [markdown]
# # Commit

# %%
# !git add .
# !git commit -m "updates via collab"
# Out:
# [main 1ff6216] updates via collab
#  7 files changed, 32 insertions(+), 120 deletions(-)
#  rewrite src/git.ipynb (96%)
#  delete mode 100644 src/train_segmentation.py
#  rewrite src/train_segmentation_drive.ipynb (98%)
#  rename src/{train_segmentation.ipynb => train_segmentation_local.ipynb} (100%)

# %% [markdown]
# # Push

# %%
# !git push origin main
# Out:
# ...
# Counting objects: 11, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 5.63 KiB | 720.00 KiB/s, done.
# Total 11 (delta 9), reused 0 (delta 0)
# remote: Resolving deltas: 100% (9/9), completed with 9 local objects.
# To github.com:RobbeRDG/barco_skin_lesion_classification.git
#    9499b66..1ff6216  main -> main

# %% [markdown]
# # SSH setup

# %%
# !ssh-keygen -t rsa -b 4096
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !cat /root/.ssh/id_rsa.pub
# Now add key to github
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:/O5crPLj/j08MwZhtsWjLyQhLsIm3BkEWoyB8N4QdYA root@34df6b5d6f38
# The key's randomart image is:
# +---[RSA 4096]----+
# |=+++o..          |
# |o+E...           |
# |. o.         .   |
# | . o.  .. . + +  |
# | ..o.o .S. + = . |
# |  o * . ....=    |
# |   o . .  .oo+   |
# |        .o.o..O  |
# |         *Oo.o.= |
# +----[SHA256]-----+
# # github.com:22 SSH-2.0-babeld-d975cc25
# ssh-rsa ... root@34df6b5d6f38

# %%
# !ssh -T git@github.com
# Out:
# ...
# git@github.com: Permission denied (publickey).

# %%
# !git remote -v
# Out:
# origin	https://github.com/RobbeRDG/barco_skin_lesion_classification.git (fetch)
# origin	https://github.com/RobbeRDG/barco_skin_lesion_classification.git (push)

# %%
git_token = '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'
# !git remote set-url origin https://{git_token}@github.com/RobbeRDG/barco_skin_lesion_classification.git
