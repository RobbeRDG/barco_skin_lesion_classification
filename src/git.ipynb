# %%
# Google drive setup
from google.colab import drive
from os.path import join
from os import chdir

MOUNT_PATH_DRIVE = '/content/drive'
BASE_PATH = join(
      MOUNT_PATH_DRIVE, 
      "MyDrive/School/2022-2023/Sem1/ai_indistrial_perspectives/barco/barco_skin_lesion_classification"
  )
CODE_PATH = join(BASE_PATH, 'src/')

# Mount the google drive
drive.mount(MOUNT_PATH_DRIVE)

# Set the base path of the project
chdir(CODE_PATH)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Config

# %%
# !git config --global user.email "robbedegroeve@gmail.com"
# !git config --global user.name "RobbeRDG"

# %% [markdown]
# # Pull

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# # Commit

# %%
# !git add .
# !git commit -m "test"
# Out:
# [main 6e9d370] test
#  13 files changed, 8 insertions(+), 8 deletions(-)
#  mode change 100755 => 100644 src/datasets/__init__.py
#  mode change 100755 => 100644 src/datasets/dermadataset.py
#  create mode 100644 src/git.ipynb
#  mode change 100755 => 100644 src/train_and_inspect.ipynb
#  mode change 100755 => 100644 src/train_and_inspect_local.ipynb
#  mode change 100755 => 100644 src/train_segmentation.ipynb
#  create mode 100644 src/train_segmentation_drive.ipynb
#  mode change 100755 => 100644 src/trainers/__init__.py
#  mode change 100755 => 100644 src/trainers/classifier_model_trainer.py
#  mode change 100755 => 100644 src/trainers/segmentation_model_trainer.py
#  mode change 100755 => 100644 src/trainers/train.py
#  mode change 100755 => 100644 src/util/__init__.py
#  mode change 100755 => 100644 src/util/config.py

# %% [markdown]
# # Push

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !ssh-keygen -t rsa -b 4096
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:NCID3qI03HS8zgJGgGsEm3hyhUewte2nmv1ittpvs3U root@db3d218d7d59
# The key's randomart image is:
# +---[RSA 4096]----+
# |* o==.           |
# |+*+*o+           |
# |B=*o= + o        |
# |oO.. = o .       |
# |+ . o . S        |
# |   . o o         |
# |    . .   . E    |
# |     =+ o. .     |
# |    +++*+o       |
# +----[SHA256]-----+

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-d975cc25

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@db3d218d7d59

# %%
# !ssh -T git@github.com
# Out:
# Warning: Permanently added the RSA host key for IP address '20.27.177.113' to the list of known hosts.
# Hi RobbeRDG! You've successfully authenticated, but GitHub does not provide shell access.
